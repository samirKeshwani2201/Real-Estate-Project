# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0         house              independent    sector 7   0.89         18658.0
# 1         house              independent   sector 14   5.00         22222.0
# 2          flat  la vida by tata housing  sector 113   2.78         10334.0
# 3         house              independent   sector 25    NaN             NaN
# 4         house   dlf city plots phase 3   sector 24   1.44         26667.0
#
#      area                                       areaWithType  bedRoom  \
# 0   477.0                         Plot area 477(44.31 sq.m.)        5
# 1  2250.0                        Plot area 250(209.03 sq.m.)        3
# 2  2690.0  Super Built up area 2690(249.91 sq.m.)Built Up...        3
# 3     NaN  Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12
# 4   540.0                          Plot area 60(50.17 sq.m.)        4
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         3       2       2.0        East    Old Property
# 1         3       3       1.0       South  Moderately Old
# 2         4      3+       5.0  North-East  Relatively New
# 3        12      3+       4.0  North-East    New Property
# 4         2       2       1.0         NaN    Old Property
#
#    super_built_up_area  built_up_area  carpet_area  servant room  study room  \
# 0                  NaN          477.0          NaN             0           0
# 1                  NaN         2250.0          NaN             0           0
# 2               2690.0         2350.0       2170.0             1           0
# 3                  NaN          260.0        245.0             1           1
# 4                  NaN          540.0          NaN             0           0
#
#    pooja room  store room  others  furnishing_type  luxury_score
# 0           0           0       0                0             8
# 1           0           0       0                0            30
# 2           0           0       0                0           220
# 3           1           0       1                1           157
# 4           0           0       0                0             8

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'],y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'],y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'],y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing the crazy outlier :

df[df['built_up_area']>700000]
# Out:
#      property_type            society      sector  price  price_per_sqft  \
# 2355          flat  hcbs sports ville  sohna road   0.35             4.0
#
#           area                           areaWithType  bedRoom  bathroom  \
# 2355  875000.0  Built Up area: 737147 (68483.2 sq.m.)        2         2
#
#      balcony  floorNum facing   agePossession  super_built_up_area  \
# 2355       2       8.0    NaN  Relatively New                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 2355       737147.0          NaN             0           0           0
#
#       store room  others  furnishing_type  luxury_score
# 2355           0       0                1            51

# %%
df=df[df['built_up_area']!=737147.0]

# %%
sns.boxplot(x=df['property_type'],y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'],y=df['price_per_sqft'],estimator=np.mean)
# Out:
# c:\Users\sk531\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'],y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>100000][['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
       'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
       'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 27           house     unitech uniworld resorts  sector 33  10.00
# 49           house                  independent  sector 12   3.50
# 164           flat           ambience caitriona  sector 24  14.00
# 242          house                  independent  sector 23   2.80
# 691          house                  independent  sector 12   6.00
# 779          house                  independent  sector 55   1.45
# 870          house  unitech nirvana birch court  sector 50   7.10
# 954          house         bhim nagar, sector 6   sector 6   0.85
# 1094         house                  independent  sector 17   3.50
# 1105         house         eros rosewood villas  sector 49   2.75
# 1166         house                dlf the grove  sector 54   5.70
# 1190         house                  independent  sector 38   8.00
# 1351         house           vipul tatvam villa  sector 48   7.25
# 1502         house                  independent  sector 28   4.50
# 1506         house     unitech uniworld resorts  sector 33   9.50
# 1707         house       dlf city plots phase 2  sector 25  10.00
# 1710         house          huda plot sector 38  sector 38   4.30
# 1831         house       unitech deerwood chase  sector 50   8.45
# 1958         house            vatika india next  sector 82   7.00
# 2271         house                  independent  sector 24  10.00
# 2338         house                  independent  sector 57   8.00
# 2363         house                  independent   sector 4   0.60
# 2641         house               uppal southend  sector 49   6.75
# 2704         house                   ardee city  sector 52   5.50
# 2760         house                    rk excelo  sector 12   0.60
# 3015         house       emaar the palm springs  sector 54  24.00
# 3319         house       dlf city plots phase 2  sector 25  10.50
# 3689         house                  independent  sector 54   3.75
# 3694         house                        ansal  sector 43   1.85
#
#       price_per_sqft   area  \
# 27          181818.0  550.0
# 49          133079.0  263.0
# 164         200000.0  700.0
# 242         161849.0  173.0
# 691         315789.0  190.0
# 779         241666.0   60.0
# 870         283333.0  251.0
# 954         126865.0   67.0
# 1094        218750.0  160.0
# 1105        178571.0  154.0
# 1166        211111.0  270.0
# 1190        230547.0  347.0
# 1351        201388.0  360.0
# 1502        125000.0  360.0
# 1506        173992.0  546.0
# 1707        400000.0  250.0
# 1710        245398.0  175.0
# 1831        235376.0  359.0
# 1958        194444.0  360.0
# 2271        229885.0  435.0
# 2338        266666.0  300.0
# 2363        105263.0   57.0
# 2641        290948.0  232.0
# 2704        183333.0  300.0
# 2760        120000.0   50.0
# 3015        600000.0  400.0
# 3319        261194.0  402.0
# 3689        234375.0  160.0
# 3694        308333.0   60.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 27                            Plot area 550(51.1 sq.m.)        5         6
# 49    Plot area 263(24.43 sq.m.)Built Up area: 4800 ...        8         8
# 164                    Built Up area: 700 (65.03 sq.m.)        4         5
# 242   Plot area 173(16.07 sq.m.)Built Up area: 160 s...        5         5
# 691   Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...        9         6
# 779                            Plot area 60(5.57 sq.m.)        4         4
# 870                           Plot area 240(22.3 sq.m.)        3         3
# 954                            Plot area 67(6.22 sq.m.)        5         2
# 1094                   Built Up area: 160 (14.86 sq.m.)        6         6
# 1105  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...        3         3
# 1166                   Built Up area: 270 (25.08 sq.m.)        4         4
# 1190  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...       10        10
# 1351                         Plot area 360(33.45 sq.m.)        4         4
# 1502                   Built Up area: 360 (33.45 sq.m.)        4         4
# 1506                         Plot area 546(50.73 sq.m.)        6         6
# 1707                         Plot area 250(23.23 sq.m.)       12        12
# 1710  Plot area 163(15.14 sq.m.)Built Up area: 145 s...       13        13
# 1831                         Plot area 359(33.35 sq.m.)        3         3
# 1958  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...        4         4
# 2271                     Carpet area: 435 (40.41 sq.m.)        8        10
# 2338                         Plot area 300(27.87 sq.m.)        5         4
# 2363                            Plot area 57(5.3 sq.m.)        3         3
# 2641                         Plot area 232(21.55 sq.m.)       12        12
# 2704                         Plot area 300(27.87 sq.m.)        9         9
# 2760  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...        5         3
# 3015                         Plot area 400(37.16 sq.m.)        5         5
# 3319                         Plot area 402(37.35 sq.m.)        4         4
# 3689                         Plot area 160(14.86 sq.m.)        4         4
# 3694                           Plot area 60(5.57 sq.m.)        8         8
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 27         3       4.0  North-East    New Property                  NaN
# 49        3+       3.0  South-East  Relatively New                  NaN
# 164        3       3.0        East       Undefined                  NaN
# 242       3+       2.0  North-East    Old Property                  NaN
# 691        2       2.0  North-East    Old Property                  NaN
# 779       3+       4.0        East  Relatively New                  NaN
# 870        3       1.0        East  Moderately Old                  NaN
# 954        2       1.0         NaN    Old Property                  NaN
# 1094      3+       3.0  North-West       Undefined                  NaN
# 1105       1       2.0  North-West    Old Property                  NaN
# 1166       0       1.0         NaN       Undefined                  NaN
# 1190      3+       1.0       North       Undefined                  NaN
# 1351       3       2.0         NaN  Relatively New                  NaN
# 1502       0       4.0         NaN       Undefined                  NaN
# 1506      3+       3.0  North-East  Moderately Old                  NaN
# 1707      3+       4.0       North  Relatively New                  NaN
# 1710      3+       5.0  North-West  Relatively New                  NaN
# 1831       2       2.0  North-East    Old Property                  NaN
# 1958      3+       3.0  North-East  Relatively New                  NaN
# 2271      3+       1.0        West       Undefined                  NaN
# 2338       3       2.0       North  Relatively New                  NaN
# 2363       1       2.0         NaN    Old Property                  NaN
# 2641      3+       NaN        West  Moderately Old                  NaN
# 2704      3+       3.0       South  Moderately Old                  NaN
# 2760       2       3.0       North  Moderately Old                  NaN
# 3015       2       1.0  North-East    Old Property                  NaN
# 3319       2       2.0        East    Old Property                  NaN
# 3689       3       3.0        East  Moderately Old                  NaN
# 3694      3+       5.0  North-West  Relatively New                  NaN
#
#       built_up_area  carpet_area
# 27            550.0          NaN
# 49           4800.0       4400.0
# 164           700.0          NaN
# 242           160.0        150.0
# 691             NaN       1600.0
# 779            60.0          NaN
# 870           240.0          NaN
# 954            67.0          NaN
# 1094          160.0          NaN
# 1105            NaN       1650.0
# 1166          270.0          NaN
# 1190          347.0        215.0
# 1351          360.0          NaN
# 1502          360.0          NaN
# 1506          546.0          NaN
# 1707          250.0          NaN
# 1710          145.0          NaN
# 1831          359.0          NaN
# 1958         3900.0       3743.0
# 2271            NaN        435.0
# 2338          300.0          NaN
# 2363           57.0          NaN
# 2641          232.0          NaN
# 2704          300.0          NaN
# 2760           30.0         15.0
# 3015          400.0          NaN
# 3319          402.0          NaN
# 3689          160.0          NaN
# 3694           60.0          NaN

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0         house              independent    sector 7   0.89         18658.0
# 1         house              independent   sector 14   5.00         22222.0
# 2          flat  la vida by tata housing  sector 113   2.78         10334.0
# 3         house              independent   sector 25    NaN             NaN
# 4         house   dlf city plots phase 3   sector 24   1.44         26667.0
#
#      area                                       areaWithType  bedRoom  \
# 0   477.0                         Plot area 477(44.31 sq.m.)        5
# 1  2250.0                        Plot area 250(209.03 sq.m.)        3
# 2  2690.0  Super Built up area 2690(249.91 sq.m.)Built Up...        3
# 3     NaN  Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12
# 4   540.0                          Plot area 60(50.17 sq.m.)        4
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         3       2       2.0        East    Old Property
# 1         3       3       1.0       South  Moderately Old
# 2         4      3+       5.0  North-East  Relatively New
# 3        12      3+       4.0  North-East    New Property
# 4         2       2       1.0         NaN    Old Property
#
#    super_built_up_area  built_up_area  carpet_area  servant room  study room  \
# 0                  NaN          477.0          NaN             0           0
# 1                  NaN         2250.0          NaN             0           0
# 2               2690.0         2350.0       2170.0             1           0
# 3                  NaN          260.0        245.0             1           1
# 4                  NaN          540.0          NaN             0           0
#
#    pooja room  store room  others  furnishing_type  luxury_score
# 0           0           0       0                0             8
# 1           0           0       0                0            30
# 2           0           0       0                0           220
# 3           1           0       1                1           157
# 4           0           0       0                0             8

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
#  flats 2,3,4 are common  
# houses 4 and 5 bhk are common
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
df[df['bedRoom']>=10]
# Out:
#      property_type                     society      sector  price  \
# 3            house                 independent   sector 25    NaN
# 66           house                 independent   sector 56   8.00
# 91           house                 independent   sector 39   7.00
# 92           house       dlf city plot phase 4   sector 28  13.00
# 169          house   floor wise designer kothi   sector 25  13.00
# ...            ...                         ...         ...    ...
# 3529         house                 independent  sector 17a   3.93
# 3542         house  unitech palms south city 1   sector 41   9.35
# 3564         house                 independent   sector 26  26.00
# 3672         house                 independent   sector 28  11.00
# 3749         house                 independent   sector 46   6.50
#
#       price_per_sqft     area  \
# 3                NaN      NaN
# 66            9654.0   8287.0
# 91           10000.0   7000.0
# 92            1992.0  65261.0
# 169          48148.0   2700.0
# ...              ...      ...
# 3529         24214.0   1623.0
# 3542         28858.0   3240.0
# 3564         82540.0   3150.0
# 3672         33951.0   3240.0
# 3749         27461.0   2367.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3     Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12        12
# 66    Plot area 362(33.63 sq.m.)Built Up area: 8286 ...       10        10
# 91    Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10        11
# 92                    Carpet area: 7250 (6061.92 sq.m.)       10        10
# 169                         Plot area 300(250.84 sq.m.)       12        16
# ...                                                 ...      ...       ...
# 3529  Plot area 1623(150.78 sq.m.)Built Up area: 162...       19        17
# 3542  Plot area 3240(301.01 sq.m.)Built Up area: 750...       10        10
# 3564  Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16        16
# 3672                        Plot area 360(301.01 sq.m.)       13        13
# 3749                         Plot area 263(219.9 sq.m.)       12        12
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 3         3+       4.0  North-East    New Property                  NaN
# 66        3+       4.0         NaN  Relatively New                  NaN
# 91        3+       4.0  South-East  Relatively New                  NaN
# 92        3+       1.0         NaN       Undefined                  NaN
# 169       3+       4.0  North-East    New Property                  NaN
# ...      ...       ...         ...             ...                  ...
# 3529       3       4.0  North-West  Relatively New                  NaN
# 3542      3+       4.0  North-East  Moderately Old                  NaN
# 3564      3+       4.0  North-West    New Property                  NaN
# 3672      3+       3.0        East  Relatively New                  NaN
# 3749      3+       4.0  North-West  Relatively New                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 3             260.0        245.0             1           1           1
# 66           8286.0          NaN             1           1           1
# 91           7000.0          NaN             0           0           1
# 92              NaN       7250.0             0           0           0
# 169          2700.0          NaN             1           1           1
# ...             ...          ...           ...         ...         ...
# 3529         1622.0          NaN             1           1           1
# 3542         7500.0       6000.0             1           1           0
# 3564          400.0        350.0             1           1           1
# 3672         3240.0          NaN             1           1           1
# 3749         2367.0          NaN             0           1           1
#
#       store room  others  furnishing_type  luxury_score
# 3              0       1                1           157
# 66             0       0                1           132
# 91             0       0                1            38
# 92             0       0                0             0
# 169            1       0                2           163
# ...          ...     ...              ...           ...
# 3529           1       0                0            89
# 3542           0       0                2            85
# 3564           1       0                1            79
# 3672           0       0                1           122
# 3749           0       0                2            39
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
df[(df['property_type']=='house')& (df['floorNum']>10)]

# reason for such high floor number are houses (villa) but in appartments
# Out:
#      property_type                  society      sector  price  \
# 346          house           ats tourmaline  sector 109   1.87
# 478          house              spaze privy   sector 72   3.10
# 537          house          godrej meridien  sector 106   5.60
# 554          house      ireo victory valley   sector 67   8.00
# 598          house               ninex city   sector 76   1.75
# 1343         house      satya the hermitage  sector 103   3.15
# 1869         house              independent   sector 92   1.80
# 1933         house         suncity township   sector 54   2.00
# 1981         house              greenopolis   sector 89   0.70
# 2160         house  indiabulls centrum park  sector 103   3.25
# 2208         house        suncity avenue 76   sector 76   0.75
# 2564         house           dlf the arbour   sector 63   8.50
# 2744         house              spaze privy   sector 72   3.09
# 3019         house   vatika the seven lamps   sector 82   1.60
#
#       price_per_sqft    area  \
# 346           8697.0  2150.0
# 478           8486.0  3653.0
# 537          14000.0  4000.0
# 554          22222.0  3600.0
# 598           6250.0  2800.0
# 1343          6702.0  4700.0
# 1869          7627.0  2360.0
# 1933         30968.0   646.0
# 1981          5397.0  1297.0
# 2160          8125.0  4000.0
# 2208         10067.0   745.0
# 2564         21519.0  3950.0
# 2744          6981.0  4426.0
# 3019          6597.0  2425.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 346                  Built Up area: 2150 (199.74 sq.m.)        3         4
# 478                        Plot area 3653(339.37 sq.m.)        5         5
# 537                        Plot area 4000(371.61 sq.m.)        5         4
# 554                         Plot area 400(334.45 sq.m.)        6         7
# 598                    Carpet area: 2800 (260.13 sq.m.)        4         4
# 1343                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 1869                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 1933  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 1981                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 2160                       Plot area 4000(371.61 sq.m.)        4         3
# 2208  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 2564                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 2744  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 3019                       Plot area 2425(225.29 sq.m.)        4         4
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 346        0      12.0         NaN           Undefined                  NaN
# 478       3+      21.0         NaN      Relatively New                  NaN
# 537       3+      33.0  North-East        New Property                  NaN
# 554       3+      51.0  North-East      Moderately Old                  NaN
# 598        0      14.0         NaN           Undefined                  NaN
# 1343       0      12.0        East           Undefined                  NaN
# 1869       0      13.0         NaN           Undefined                  NaN
# 1933       3      11.0       North      Relatively New                  NaN
# 1981       2      14.0  North-East           Undefined                  NaN
# 2160      3+      20.0         NaN  Under Construction                  NaN
# 2208       2      11.0  North-East        New Property                  NaN
# 2564      3+      27.0         NaN           Undefined                  NaN
# 2744      3+      14.0        East      Relatively New                  NaN
# 3019      3+      16.0       North      Moderately Old                  NaN
#
#       built_up_area  carpet_area  servant room  study room  pooja room  \
# 346          2150.0          NaN             0           0           0
# 478          3653.0          NaN             0           0           0
# 537          4000.0          NaN             1           1           1
# 554          3600.0          NaN             1           1           1
# 598             NaN       2800.0             0           0           0
# 1343         4700.0          NaN             0           0           0
# 1869         2360.0          NaN             0           0           0
# 1933           60.0         59.0             1           0           0
# 1981         1297.0          NaN             0           0           0
# 2160         4000.0          NaN             0           0           0
# 2208          745.0          NaN             0           0           0
# 2564         3950.0          NaN             0           0           0
# 2744         3653.0       2922.0             1           0           0
# 3019         2425.0          NaN             1           0           0
#
#       store room  others  furnishing_type  luxury_score
# 346            0       0                0             0
# 478            0       0                0             0
# 537            1       0                0           190
# 554            0       0                2            56
# 598            0       0                0             0
# 1343           0       0                0            65
# 1869           0       0                0             0
# 1933           0       0                1             7
# 1981           0       0                0             0
# 2160           0       0                0            57
# 2208           0       0                0            47
# 2564           0       0                0            68
# 2744           0       0                2            48
# 3019           0       0                0           116

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
df[['price','furnishing_type','luxury_score']].sample(5)
# Out:
#       price  furnishing_type  luxury_score
# 1516   2.45                1           220
# 1974  12.50                0            62
# 1768   6.80                2           137
# 2694   1.75                2           129
# 1230   1.30                0            61

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0         house              independent    sector 7   0.89         18658.0
# 1         house              independent   sector 14   5.00         22222.0
# 2          flat  la vida by tata housing  sector 113   2.78         10334.0
# 3         house              independent   sector 25    NaN             NaN
# 4         house   dlf city plots phase 3   sector 24   1.44         26667.0
#
#      area                                       areaWithType  bedRoom  \
# 0   477.0                         Plot area 477(44.31 sq.m.)        5
# 1  2250.0                        Plot area 250(209.03 sq.m.)        3
# 2  2690.0  Super Built up area 2690(249.91 sq.m.)Built Up...        3
# 3     NaN  Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12
# 4   540.0                          Plot area 60(50.17 sq.m.)        4
#
#    bathroom balcony  floorNum      facing   agePossession  \
# 0         3       2       2.0        East    Old Property
# 1         3       3       1.0       South  Moderately Old
# 2         4      3+       5.0  North-East  Relatively New
# 3        12      3+       4.0  North-East    New Property
# 4         2       2       1.0         NaN    Old Property
#
#    super_built_up_area  built_up_area  carpet_area  servant room  study room  \
# 0                  NaN          477.0          NaN             0           0
# 1                  NaN         2250.0          NaN             0           0
# 2               2690.0         2350.0       2170.0             1           0
# 3                  NaN          260.0        245.0             1           1
# 4                  NaN          540.0          NaN             0           0
#
#    pooja room  store room  others  furnishing_type  luxury_score
# 0           0           0       0                0             8
# 1           0           0       0                0            30
# 2           0           0       0                0           220
# 3           1           0       1                1           157
# 4           0           0       0                0             8

# %%
# sector analysis :

plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis :

import re
avg_price_per_sector=df.groupby('sector')['price'].mean().reset_index()
def extract_sector_number(sector_name):
    match=re.search(r'\d+',sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')
avg_price_per_sector['sector_number']=avg_price_per_sector['sector'].apply(extract_sector_number)
avg_price_per_sector_sorted_by_sector=avg_price_per_sector.sort_values(by='sector_number')

#plot the heatmap 
plt.figure(figsize=(5,25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']],annot=True,fmt=".2f",linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()
